# %%
# %matplotlib widget

# %%
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
x=range(1990,2022)
y=np.random.rand(32)
z = np.sin( np.linspace(0, 20, 32) )
print(len(z))
# Out:
# 32

# %%
plt.plot(x,z)
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Value price from 1990 to 2022')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
